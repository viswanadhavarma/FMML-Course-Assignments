# %% [markdown]
# <a href="https://colab.research.google.com/github/viswanadhavarma/FMML-Course-Assignments/blob/main/FMML_Module_9_Lab4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Module 9: Convolutional Neural Networks
# ## **Lab 4**
# ### Module coordinator: Kushagra Agarwal

# %% [markdown]
# <img src="https://miro.medium.com/max/1200/1*QoqNAg2t6lF8Q6WWA6AbOg.png" width=650px/>

# %% [markdown]
# ## Using learnt representations
# In practice, very few people train an entire Convolutional Network from scratch (with random initialization), because it is relatively rare to have a dataset of sufficient size. Instead, it is common to pretrain a ConvNet on a very large dataset (e.g. ImageNet, which contains 1.2 million images with 1000 categories), and then use the ConvNet either as an initialization or a fixed feature extractor for the task of interest.
#
#
# We'll train a model to classify ants and bees. We have about 120 training images each for ants and bees. There are 75 validation images for each class. Usually, this is a very small dataset to generalize upon, if trained from scratch. Since we are using transfer learning, we should be able to generalize reasonably well.
#
# This dataset is a very small subset of imagenet.

# %%
# Import packages
import torch
import torchvision
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader, SubsetRandomSampler
import torch.nn as nn
from torch import optim
import torch.nn.functional as F

import matplotlib.pyplot as plt
import numpy as np
import time
import os

# %%
# Device configuration (whether to run on GPU or CPU)
device = 'cpu' #torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# Download and extract dataset
# !wget https://download.pytorch.org/tutorial/hymenoptera_data.zip
# !unzip -q hymenoptera_data.zip
# Out:
# --2023-06-10 14:19:35--  https://download.pytorch.org/tutorial/hymenoptera_data.zip
# Resolving download.pytorch.org (download.pytorch.org)... 18.160.200.126, 18.160.200.112, 18.160.200.71, ...
# Connecting to download.pytorch.org (download.pytorch.org)|18.160.200.126|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 47286322 (45M) [application/zip]
# Saving to: ‘hymenoptera_data.zip.1’
#
# hymenoptera_data.zi 100%[===================>]  45.10M   194MB/s    in 0.2s
#
# 2023-06-10 14:19:36 (194 MB/s) - ‘hymenoptera_data.zip.1’ saved [47286322/47286322]
#
# replace hymenoptera_data/train/ants/0013035.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace hymenoptera_data/train/ants/1030023514_aad5c608f9.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace hymenoptera_data/train/ants/1095476100_3906d8afde.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace hymenoptera_data/train/ants/1099452230_d1949d3250.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace hymenoptera_data/train/ants/116570827_e9c126745d.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace hymenoptera_data/train/ants/1225872729_6f0856588f.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace hymenoptera_data/train/ants/1262877379_64fcada201.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace hymenoptera_data/train/ants/1269756697_0bce92cdab.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace hymenoptera_data/train/ants/1286984635_5119e80de1.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace hymenoptera_data/train/ants/132478121_2a430adea2.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace hymenoptera_data/train/ants/1360291657_dc248c5eea.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace hymenoptera_data/train/ants/1368913450_e146e2fb6d.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace hymenoptera_data/train/ants/1473187633_63ccaacea6.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace hymenoptera_data/train/ants/148715752_302c84f5a4.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace hymenoptera_data/train/ants/1489674356_09d48dde0a.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace hymenoptera_data/train/ants/149244013_c529578289.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace hymenoptera_data/train/ants/150801003_3390b73135.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace hymenoptera_data/train/ants/150801171_cd86f17ed8.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace hymenoptera_data/train/ants/154124431_65460430f2.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace hymenoptera_data/train/ants/162603798_40b51f1654.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace hymenoptera_data/train/ants/1660097129_384bf54490.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: yu
# replace hymenoptera_data/train/ants/167890289_dd5ba923f3.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace hymenoptera_data/train/ants/1693954099_46d4c20605.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace hymenoptera_data/train/ants/175998972.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace hymenoptera_data/train/ants/178538489_bec7649292.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace hymenoptera_data/train/ants/1804095607_0341701e1c.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace hymenoptera_data/train/ants/1808777855_2a895621d7.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace hymenoptera_data/train/ants/188552436_605cc9b36b.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace hymenoptera_data/train/ants/1917341202_d00a7f9af5.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace hymenoptera_data/train/ants/1924473702_daa9aacdbe.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace hymenoptera_data/train/ants/196057951_63bf063b92.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace hymenoptera_data/train/ants/196757565_326437f5fe.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace hymenoptera_data/train/ants/201558278_fe4caecc76.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace hymenoptera_data/train/ants/201790779_527f4c0168.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace hymenoptera_data/train/ants/2019439677_2db655d361.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename:
# error:  invalid response [{ENTER}]
# replace hymenoptera_data/train/ants/2019439677_2db655d361.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace hymenoptera_data/train/ants/207947948_3ab29d7207.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace hymenoptera_data/train/ants/20935278_9190345f6b.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename:
# error:  invalid response [{ENTER}]
# replace hymenoptera_data/train/ants/20935278_9190345f6b.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace hymenoptera_data/train/ants/224655713_3956f7d39a.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace hymenoptera_data/train/ants/2265824718_2c96f485da.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# y
# replace hymenoptera_data/train/ants/2265825502_fff99cfd2d.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: replace hymenoptera_data/train/ants/226951206_d6bf946504.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: yy
# replace hymenoptera_data/train/ants/2278278459_6b99605e50.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace hymenoptera_data/train/ants/2288450226_a6e96e8fdf.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace hymenoptera_data/train/ants/2288481644_83ff7e4572.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: yy
# replace hymenoptera_data/train/ants/2292213964_ca51ce4bef.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace hymenoptera_data/train/ants/24335309_c5ea483bb8.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace hymenoptera_data/train/ants/245647475_9523dfd13e.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace hymenoptera_data/train/ants/255434217_1b2b3fe0a4.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename:
# error:  invalid response [{ENTER}]
# replace hymenoptera_data/train/ants/255434217_1b2b3fe0a4.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace hymenoptera_data/train/ants/258217966_d9d90d18d3.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace hymenoptera_data/train/ants/275429470_b2d7d9290b.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename:
# error:  invalid response [{ENTER}]
# replace hymenoptera_data/train/ants/275429470_b2d7d9290b.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace hymenoptera_data/train/ants/28847243_e79fe052cd.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: yy
# replace hymenoptera_data/train/ants/318052216_84dff3f98a.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace hymenoptera_data/train/ants/334167043_cbd1adaeb9.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace hymenoptera_data/train/ants/339670531_94b75ae47a.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# y
# replace hymenoptera_data/train/ants/342438950_a3da61deab.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: replace hymenoptera_data/train/ants/36439863_0bec9f554f.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace hymenoptera_data/train/ants/374435068_7eee412ec4.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace hymenoptera_data/train/ants/382971067_0bfd33afe0.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace hymenoptera_data/train/ants/384191229_5779cf591b.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: yy
# replace hymenoptera_data/train/ants/386190770_672743c9a7.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace hymenoptera_data/train/ants/392382602_1b7bed32fa.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# y
# replace hymenoptera_data/train/ants/403746349_71384f5b58.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: replace hymenoptera_data/train/ants/408393566_b5b694119b.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace hymenoptera_data/train/ants/424119020_6d57481dab.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace hymenoptera_data/train/ants/424873399_47658a91fb.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace hymenoptera_data/train/ants/450057712_771b3bfc91.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: yy
# replace hymenoptera_data/train/ants/45472593_bfd624f8dc.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: A

# %%
# Data augmentation and normalization for training
# Just normalization for validation
train_transform = transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])
val_transform = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])

data_dir = './hymenoptera_data'
train_dataset = ImageFolder(os.path.join(data_dir, 'train'), train_transform)
val_dataset = ImageFolder(os.path.join(data_dir, 'val'), val_transform)
train_dataloader = DataLoader(train_dataset, batch_size=4,shuffle=True, num_workers=2)
val_dataloader = DataLoader(val_dataset, batch_size=4,shuffle=True, num_workers=2)
class_names = train_dataset.classes

# %%
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated


# Get a batch of training data
inputs, classes = next(iter(train_dataloader))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

imshow(out, title=[class_names[x] for x in classes])

# %%
def train_model(model, train_dataloader, criterion, optimizer, num_epochs=25):

    for epoch in range(num_epochs):
        print(f'Epoch {epoch}/{num_epochs - 1}')
        print('-' * 10)
        model.train()
        running_loss = 0.0
        running_corrects = 0

        # Iterate over data.
        for i, (inputs, labels) in enumerate(train_dataloader):
            inputs = inputs.to(device)
            labels = labels.to(device)

            # zero the parameter gradients
            optimizer.zero_grad()

            # forward
            # track history if only in train
            with torch.set_grad_enabled(True):
              outputs = model(inputs)
              _, preds = torch.max(outputs, 1)
              loss = criterion(outputs, labels)

              # backward + optimize only if in training phase
              loss.backward()
              optimizer.step()

            # statistics
            running_loss += loss.item() * inputs.size(0)
            running_corrects += torch.sum(preds == labels.data)

        epoch_loss = running_loss / len(train_dataloader.dataset)
        epoch_acc = running_corrects.double() / len(train_dataloader.dataset)

        print(f'Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

        print()

# %%
def visualize_model(model, num_images=10):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(val_dataloader):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title(f'predicted: {class_names[preds[j]]}')
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %%
from torchvision import models

model_ft = models.resnet18(pretrained=True)
num_ftrs = model_ft.fc.in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
model_ft.fc = nn.Linear(num_ftrs, 2)

model_ft = model_ft.to(device)

loss_func = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.9)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
num_epochs = 5
train_model(model_ft, train_dataloader, loss_func, optimizer, num_epochs)
# Out:
# Epoch 0/4
# ----------
# Loss: 0.5599 Acc: 0.7295
#
# Epoch 1/4
# ----------
# Loss: 0.6292 Acc: 0.7172
#
# Epoch 2/4
# ----------
# Loss: 0.5401 Acc: 0.7828
#
# Epoch 3/4
# ----------
# Loss: 0.3684 Acc: 0.8197
#
# Epoch 4/4
# ----------
# Loss: 0.6415 Acc: 0.7582

# %%
visualize_model(model_ft)

# %% [markdown]
# ## Example of How Pretrained models are used for Target Tasks

# %% [markdown]
# <img src="https://www.researchgate.net/publication/340225334/figure/fig2/AS:960014822944773@1605896778155/Mechanism-of-transfer-learning-using-pre-trained-models.png" width=950px/>

# %% [markdown]
# ## Questions:
# 1) What is the significance of using data augmentations like resize, crop etc on training data?
#
# 2) What performance do you get if you don't use pretrained resnet model (Hint: Change pretrained=False and train the model)
#
# 3) If the resnet model was pre-trained on dataset significantly different than the ants vs bees data, would you still get good performance by using this pretrained model?

# %% [markdown]
# # Answer-1
#
# It increases the number of examples in the training set and also in the validation set while also introducing more variety in what the model sees and learns from.

# %% [markdown]
# # Answer-2

# %%
from torchvision import models
model_ft = models.resnet18(pretrained=False)
num_ftrs = model_ft.fc.in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
model_ft.fc = nn.Linear(num_ftrs, 2)

model_ft = model_ft.to(device)

loss_func = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.9)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)

# %%
num_epochs = 5
train_model(model_ft, train_dataloader, loss_func, optimizer, num_epochs)
# Out:
# Epoch 0/4
# ----------
# Loss: 1.0646 Acc: 0.4221
#
# Epoch 1/4
# ----------
# Loss: 0.8104 Acc: 0.5492
#
# Epoch 2/4
# ----------
# Loss: 0.7566 Acc: 0.6025
#
# Epoch 3/4
# ----------
# Loss: 0.7015 Acc: 0.6230
#
# Epoch 4/4
# ----------
# Loss: 0.7790 Acc: 0.5943

# %%
visualize_model(model_ft)

# %% [markdown]
# Accuracy was less because the model has been already trained on large data.

# %% [markdown]
# # Answer-3
#
# The performance on the ants vs bees dataset may be affected if the pre-training dataset is significantly different.  If the pre-training dataset is significantly different from the ants vs bees data, the performance of the pre-trained model may not be as good as expected.
